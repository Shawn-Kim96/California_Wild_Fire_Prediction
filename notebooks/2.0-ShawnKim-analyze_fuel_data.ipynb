# %%
import os
import sys
import time
import pandas as pd
from datetime import datetime, timedelta
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
from dbfread import DBF
import rasterio
from tqdm import tqdm

# Add project path to os.path
current_path = os.path.abspath('.')
project_name = 'California_Wild_Fire_Prediction'
project_path = os.path.join(current_path.split(project_name)[0], project_name)
print(project_path)
sys.path.append(project_path)
load_dotenv('.env')
# Out:
# /Users/shawn/Documents/sjsu/2025-1/ML_CMPE257/California_Wild_Fire_Prediction
# False

# %%
fire_df = pd.read_csv("/Users/shawn/Documents/sjsu/2025-1/ML_CMPE257/California_Wild_Fire_Prediction/data/calfire_cimis_data/processed/finalized/calfire_cimis_all_rows.csv")
fire_df.head(3)
# Out:
#                             incident_id incident_name  \
# 0  2ca11d45-8139-4c16-8af0-880d99b21e82   Bridge Fire
# 1  f904489b-0488-4764-9a98-bd3b818d1756      111 Fire
# 2  f9e85371-fc46-4f54-822c-7dcdaadde551      152 Fire
#
#   incident_date_last_update incident_date_created  incident_acres_burned  \
# 0      2018-01-09T13:46:00Z  2017-10-31T11:22:00Z                   37.0
# 1      2022-05-01T22:29:02Z  2022-04-30T20:33:00Z                   15.0
# 2      2013-06-05T08:30:00Z  2013-06-04T15:42:00Z                  124.0
#
#    incident_longitude  incident_latitude incident_dateonly_created  \
# 0         -122.309000          40.774000                2017-10-31
# 1         -115.916687          33.510716                2022-04-30
# 2         -121.006939          37.037760                2013-06-04
#
#    DayAirTmpAvg01  DayPrecip01  ...  DayAirTmpAvg13  DayPrecip13  \
# 0             9.6          0.0  ...            10.2          0.0
# 1            22.3          0.0  ...            22.4          0.0
# 2            20.2          0.0  ...            23.8          0.0
#
#    DayRelHumAvg13  DaySoilTmpAvg13  DayWindSpdAvg13  DayAirTmpAvg14  \
# 0            62.0             12.1              0.8             9.5
# 1            38.0             22.2              3.2            22.8
# 2            43.0             20.5              4.0            22.0
#
#    DayPrecip14  DayRelHumAvg14  DaySoilTmpAvg14  DayWindSpdAvg14
# 0          0.0            66.0             11.9              2.8
# 1          0.0            33.0             22.7              2.0
# 2          0.0            50.0             20.7              4.2
#
# [3 rows x 78 columns]

# %%
import folium

lat_list = fire_df.incident_latitude
lng_list = fire_df.incident_longitude

m = folium.Map(location=[lat_list[0], lng_list[0]], zoom_start=6)

for lat, lng in zip(lat_list, lng_list):
    folium.Marker(location=[lat, lng]).add_to(m)

m.save("map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_711a98d1dc94f77e05b0feeaf1123c8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_711a98d1dc94f77e05b0feeaf1123c8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_711a98d1dc94f77e05b0feeaf1123c8c = L.map(
#                 &quot;map_711a98d1dc94f77e05b0feeaf1123c8c&quot;,
#                 {
#                     center: [40.774, -122.309],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af6e5edc3f7a8127e418b6a30fc0c58c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af6e5edc3f7a8127e418b6a30fc0c58c.addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_ae4eef273e3b5feb66281283af770a62 = L.marker(
#                 [40.774, -122.309],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_b2986af93bcd2f6131d641cd98f5d0e5 = L.marker(
#                 [33.510716, -115.916687],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_934d574afef0943c6ee443dfa1e5871a = L.marker(
#                 [37.03776, -121.006939],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_235f3334d36895527e17ee952d3048be = L.marker(
#                 [33.7626, -117.7274],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_ea3112d92e54039f04a45c840fe1e25a = L.marker(
#                 [41.4435, -120.87054],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_90097633b684608589d6eb7aef52b944 = L.marker(
#                 [40.95234, -121.21597],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_0d2b5d4a3ba3662f541f75dfa879fbb5 = L.marker(
#                 [41.29226, -121.172117],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_bd8e13738cafda3e95a5e7eebd2e4cf7 = L.marker(
#                 [40.856422, -121.101623],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_8f63f6df1397f1c3028bd249507916bf = L.marker(
#                 [40.94666, -121.27049],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_7f9e3867dc38c655a940145daa84eaa7 = L.marker(
#                 [41.08583, -121.05722],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_1a3186b8ee30ac0f691ce6b4d5ab20b9 = L.marker(
#                 [39.99309, -120.02137],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_8f7cb94219b409bc7ed95d03c900d2b2 = L.marker(
#                 [40.900458, -121.320838],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_d7d598a50e8271e711884d6d1b13e255 = L.marker(
#                 [41.060445, -121.211449],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_6dc22e71e21f42adc38cb8ed2417ae36 = L.marker(
#                 [39.8255, -121.7127],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_3b5f67327c3331df83cdee70b5a3abf8 = L.marker(
#                 [40.20077, -122.24731],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_f36db820af7cb39e515305eade4abc98 = L.marker(
#                 [40.3506868, -121.7786799],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_c9bfdd15c21a0c9840ec1ca1f20a3c28 = L.marker(
#                 [38.14242, -122.47301],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_afec847a7a2e56d4511beaad25adae89 = L.marker(
#                 [41.64469, -120.31814],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_42035c6cab7cca60536b07edec5e9825 = L.marker(
#                 [41.562302, -120.497502],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_c74f9a53d4824a1b7e59244190bbd402 = L.marker(
#                 [41.4844, -120.36659],
#                 {
# }
#             ).addTo(map_711a98d1dc94f77e05b0feeaf1123c8c);
#
#
#             var marker_5ae3eae2ccf2613dd8d6f5ea2d96d8c7 = L.marker(
#                 [33.9859

# %% [markdown]
# # Extract data from LANDFIRE.gov

# %%
data_dir = "/Users/shawn/Downloads/landfire_bdq7AFNARJrHJo3233me/"
data_hashmap = {}

for _data in os.listdir(data_dir):
    if _data == '.DS_Store':
        continue
    
    data_name = _data.split('_')[1]
    dbf_path, tif_path = '', ''
    for _file in os.listdir(os.path.join(data_dir, _data)):
        if 'vat.dbf' in _file:
            dbf_path = os.path.join(data_dir, _data, _file)
        if _file.split('.')[-1] == 'tif':
            tif_path = os.path.join(data_dir, _data, _file)
    
    if not (len(dbf_path) or len(tif_path)):
        continue

    data_hashmap[data_name] = {
        'dbf': pd.DataFrame(iter(DBF(dbf_path, load=True))),
        'tif': tif_path
    }
    
print(data_hashmap.keys())
# Out:
# dict_keys(['FDist', 'FVC', 'CBD', 'FBFM40', 'EVC', 'FBFM13'])

# %% [markdown]
# ## CBD (Canopy Bulk Density) data

# %% [markdown]
# How dense the forest canopy fuels are, vertically. This is important for modeling crown fire intensity.

# %%
# Load VALUE → label mapping
vat_df, tif_path = data_hashmap['CBD'].values()
value_to_label = dict(zip(vat_df["VALUE"], vat_df["KGM3"]))

# Load raster and extract valid pixels
with rasterio.open(tif_path) as src:
    band = src.read(1)
    transform = src.transform
    nodata = src.nodata

    mask = (band != nodata) & (band != 0)
    rows, cols = np.where(mask)
    
    # Sample fewer if needed (for speed)
    SAMPLE_SIZE = 500_000
    if len(rows) > SAMPLE_SIZE:
        indices = np.random.choice(len(rows), size=SAMPLE_SIZE, replace=False)
        rows = rows[indices]
        cols = cols[indices]

    lats, lngs, vals = [], [], []

    for r, c in tqdm(zip(rows, cols), total=len(rows)):
        lng, lat = rasterio.transform.xy(transform, r, c)
        v = band[r, c]
        label = value_to_label.get(v)
        if label:
            lats.append(lat)
            lngs.append(lng)
            vals.append(v)

# Create cbd_df
cbd_df = pd.DataFrame({
    "latitude": lats,
    "longitude": lngs,
    "CBD_VALUE": vals
})
# Out:
# 100%|██████████| 500000/500000 [00:05<00:00, 85018.36it/s]

# %%
cbd_df.to_csv(os.path.join(project_path, "data/landfire_data/processed/cbd_data.csv"))

# %%
# Build KDTree on cbd_df
cbd_coords = np.radians(cbd_df[["latitude", "longitude"]].values)
tree = sklearn.neighbors.BallTree(cbd_coords, metric='haversine')

# Query nearest neighbors for fire_df coords
fire_coords = np.radians(fire_df[["incident_latitude", "incident_longitude"]].values)
dist, idx = tree.query(fire_coords, k=1)

# Add matched CBD info to fire_df
matched = cbd_df.iloc[idx.flatten()].reset_index(drop=True)
fire_df["CBD_VALUE"] = matched["CBD_VALUE"]
fire_df["CBD_LABEL"] = matched["CBD_VALUE"].map(value_to_label)
fire_df["CBD_DISTANCE_KM"] = dist.flatten() * 6371  # Convert from radians to km

# %% [markdown]
# ## Existing Vegetation Cover (EVC)

# %% [markdown]
# How much ground is covered by vegetation, includes grasses, shrubs, trees

# %%
vat_df, tif_path = data_hashmap['EVC'].values()
vat_df.head(4)
# Out:
#    VALUE    COUNT                         CLASSNAMES    R    G    B       RED  \
# 0  -9999  1512576                        Fill-NoData  255  255  255  1.000000
# 1     11  9615374                         Open Water    0    0  255  0.000000
# 2     12    40405                           Snow/Ice  159  161  240  0.623529
# 3     13   301351  Developed-Upland Deciduous Forest   64   61  168  0.250980
#
#       GREEN      BLUE
# 0  1.000000  1.000000
# 1  0.000000  1.000000
# 2  0.631373  0.941176
# 3  0.239216  0.658824

# %%
vat_df, tif_path = data_hashmap['EVC'].values()
value_to_label = dict(zip(vat_df["VALUE"], vat_df["CLASSNAMES"]))

# Load raster and extract valid pixels
with rasterio.open(tif_path) as src:
    band = src.read(1)
    transform = src.transform
    nodata = src.nodata

    mask = (band != nodata) & (band != 0)
    rows, cols = np.where(mask)
    
    # Sample fewer if needed (for speed)
    SAMPLE_SIZE = 500_000
    if len(rows) > SAMPLE_SIZE:
        indices = np.random.choice(len(rows), size=SAMPLE_SIZE, replace=False)
        rows = rows[indices]
        cols = cols[indices]

    lats, lngs, vals = [], [], []

    for r, c in tqdm(zip(rows, cols), total=len(rows)):
        lng, lat = rasterio.transform.xy(transform, r, c)
        v = band[r, c]
        label = value_to_label.get(v)
        if label:
            lats.append(lat)
            lngs.append(lng)
            vals.append(v)


evc_df = pd.DataFrame({
    "latitude": lats,
    "longitude": lngs,
    "EVC_VALUE": vals
})
# Out:
# 100%|██████████| 500000/500000 [00:06<00:00, 80709.65it/s]

# %%
evc_df.to_csv(os.path.join(project_path, "data/landfire_data/processed/evc_data.csv"))

# %%
evc_coords = np.radians(evc_df[["latitude", "longitude"]].values)
tree = sklearn.neighbors.BallTree(evc_coords, metric='haversine')

# Query nearest neighbors for fire_df coords
fire_coords = np.radians(fire_df[["incident_latitude", "incident_longitude"]].values)
dist, idx = tree.query(fire_coords, k=1)

# Add matched CBD info to fire_df
matched = evc_df.iloc[idx.flatten()].reset_index(drop=True)
fire_df["EVC_VALUE"] = matched["EVC_VALUE"]
fire_df["EVC_LABEL"] = matched["EVC_VALUE"].map(value_to_label)
fire_df["EVC_DISTANCE_KM"] = dist.flatten() * 6371  # Convert from radians to km

# %% [markdown]
# ## FBFM13

# %% [markdown]
# Fire Behavior Fuel Model 13, classic 13 fire fuel models based on vegetation type and fire bahvior.
#
# - 1: Short grass
# - 2: Timber
# - 3: Tall grass
# - 4: Chaparral
# - 5: Brush
# - 6: Dormant brush, hardwood slash
# - 7: Southern rough
# - 8: Closed timber litter
# - 9: Hardwood litter
# - 10: Timber (litter and understory)
# - 11: Light logging slash
# - 12: Medium logging slash
# - 13: Heavy logging slash

# %%
vat_df, tif_path = data_hashmap['FBFM13'].values()
vat_df.head(4)
# Out:
#    VALUE     COUNT       FBFM13    R    G    B  RED     GREEN      BLUE
# 0  -9999   1512576  Fill-NoData  255  255  255  1.0  1.000000  1.000000
# 1      2  74531382        FBFM2  255  255    0  1.0  1.000000  0.000000
# 2      4  12164024        FBFM4  255  211  127  1.0  0.827451  0.498039
# 3      5  83824454        FBFM5  255  170  102  1.0  0.666667  0.400000

# %%
vat_df, tif_path = data_hashmap['FBFM13'].values()

# Load raster and extract valid pixels
with rasterio.open(tif_path) as src:
    band = src.read(1)
    transform = src.transform
    nodata = src.nodata

    mask = (band != nodata) & (band != 0)
    rows, cols = np.where(mask)
    
    # Sample fewer if needed (for speed)
    SAMPLE_SIZE = 500_000
    if len(rows) > SAMPLE_SIZE:
        indices = np.random.choice(len(rows), size=SAMPLE_SIZE, replace=False)
        rows = rows[indices]
        cols = cols[indices]

    lats, lngs, vals = [], [], []

    for r, c in tqdm(zip(rows, cols), total=len(rows)):
        lng, lat = rasterio.transform.xy(transform, r, c)
        v = band[r, c]
        label = value_to_label.get(v)
        if label:
            lats.append(lat)
            lngs.append(lng)
            vals.append(v)


fbfm_df = pd.DataFrame({
    "latitude": lats,
    "longitude": lngs,
    "FBFM_VALUE": vals
})
# Out:
# 100%|██████████| 500000/500000 [00:05<00:00, 83757.87it/s]

# %%
fbfm_df.to_csv(os.path.join(project_path, "data/landfire_data/processed/fbfm_data.csv"))

# %%
fbfm_coords = np.radians(fbfm_df[["latitude", "longitude"]].values)
tree = sklearn.neighbors.BallTree(fbfm_coords, metric='haversine')

fire_coords = np.radians(fire_df[["incident_latitude", "incident_longitude"]].values)
dist, idx = tree.query(fire_coords, k=1)

matched = fbfm_df.iloc[idx.flatten()].reset_index(drop=True)
fire_df["FBFM_VALUE"] = matched["FBFM_VALUE"]
fire_df["FBFM_DISTANCE_KM"] = dist.flatten() * 6371  # Convert from radians to km

# %% [markdown]
# ## Fuel Distrubance (FDist)

# %% [markdown]
# Fuel Disturbance, Recent disturbance to fuels like thinning, harvest, fire, windothrow, etc.

# %%
vat_df, tif_path = data_hashmap['FDist'].values()
vat_df.head(4)
# Out:
#    VALUE      COUNT          D_TYPE D_SEVERITY             D_TIME    R    G  \
# 0  -9999    1512576     Fill-NoData         NA                 NA  255  255
# 1      0  308221079  No Disturbance         NA                 NA    0    0
# 2    111    1279155            Fire        Low           One Year  214   96
# 3    112   18626896            Fire        Low  Two to Five Years  214   96
#
#      B       RED     GREEN      BLUE
# 0  255  1.000000  1.000000  1.000000
# 1    0  0.000000  0.000000  0.000000
# 2   77  0.839216  0.376471  0.301961
# 3   77  0.839216  0.376471  0.301961

# %%
vat_df, tif_path = data_hashmap['FDist'].values()
value_to_label = dict(zip(vat_df["VALUE"], vat_df['D_TYPE'] + '/' + vat_df['D_SEVERITY'] + '/' + vat_df['D_TIME']))

# Load raster and extract valid pixels
with rasterio.open(tif_path) as src:
    band = src.read(1)
    transform = src.transform
    nodata = src.nodata

    mask = (band != nodata) & (band != 0)
    rows, cols = np.where(mask)
    
    # Sample fewer if needed (for speed)
    SAMPLE_SIZE = 500_000
    if len(rows) > SAMPLE_SIZE:
        indices = np.random.choice(len(rows), size=SAMPLE_SIZE, replace=False)
        rows = rows[indices]
        cols = cols[indices]

    lats, lngs, vals = [], [], []

    for r, c in tqdm(zip(rows, cols), total=len(rows)):
        lng, lat = rasterio.transform.xy(transform, r, c)
        v = band[r, c]
        label = value_to_label.get(v)
        if label:
            lats.append(lat)
            lngs.append(lng)
            vals.append(v)


fdist_df = pd.DataFrame({
    "latitude": lats,
    "longitude": lngs,
    "FDIST_VALUE": vals
})

fdist_df.to_csv(os.path.join(project_path, "data/landfire_data/processed/fdist_data.csv"))
# Out:
# 100%|██████████| 500000/500000 [00:05<00:00, 84572.92it/s]

# %%
fdist_coords = np.radians(fdist_df[["latitude", "longitude"]].values)
tree = sklearn.neighbors.BallTree(fdist_coords, metric='haversine')

fire_coords = np.radians(fire_df[["incident_latitude", "incident_longitude"]].values)
dist, idx = tree.query(fire_coords, k=1)

matched = fdist_df.iloc[idx.flatten()].reset_index(drop=True)
fire_df["FDIST_VALUE"] = matched["FDIST_VALUE"]
fire_df["FDIST_DISTANCE_KM"] = dist.flatten() * 6371  # Convert from radians to km

# %% [markdown]
# ## Fuel Vegetation Cover (FVC)

# %% [markdown]
# Similar to EVC, but more focused on fuel-relevant vegetation, helps estimate surface fuel continuity

# %%
vat_df, tif_path = data_hashmap['FVC'].values()
vat_df.head(4)
# Out:
#    VALUE    COUNT                         CLASSNAMES    R    G    B       RED  \
# 0  -9999  1512576                        Fill-NoData  255  255  255  1.000000
# 1     11  9615374                         Open Water    0    0  255  0.000000
# 2     12    40405                           Snow/Ice  159  161  240  0.623529
# 3     13   347404  Developed-Upland Deciduous Forest   64   61  168  0.250980
#
#       GREEN      BLUE
# 0  1.000000  1.000000
# 1  0.000000  1.000000
# 2  0.631373  0.941176
# 3  0.239216  0.658824

# %%
vat_df, tif_path = data_hashmap['FVC'].values()
value_to_label = dict(zip(vat_df["VALUE"], vat_df["CLASSNAMES"]))

# Load raster and extract valid pixels
with rasterio.open(tif_path) as src:
    band = src.read(1)
    transform = src.transform
    nodata = src.nodata

    mask = (band != nodata) & (band != 0)
    rows, cols = np.where(mask)
    
    # Sample fewer if needed (for speed)
    SAMPLE_SIZE = 500_000
    if len(rows) > SAMPLE_SIZE:
        indices = np.random.choice(len(rows), size=SAMPLE_SIZE, replace=False)
        rows = rows[indices]
        cols = cols[indices]

    lats, lngs, vals = [], [], []

    for r, c in tqdm(zip(rows, cols), total=len(rows)):
        lng, lat = rasterio.transform.xy(transform, r, c)
        v = band[r, c]
        label = value_to_label.get(v)
        if label:
            lats.append(lat)
            lngs.append(lng)
            vals.append(v)


fvc_df = pd.DataFrame({
    "latitude": lats,
    "longitude": lngs,
    "FVC_VALUE": vals
})

fvc_df.to_csv(os.path.join(project_path, "data/landfire_data/processed/fvc_data.csv"))
# Out:
# 100%|██████████| 500000/500000 [00:06<00:00, 82968.30it/s]

# %%
fvc_coords = np.radians(fvc_df[["latitude", "longitude"]].values)
tree = sklearn.neighbors.BallTree(fvc_coords, metric='haversine')

fire_coords = np.radians(fire_df[["incident_latitude", "incident_longitude"]].values)
dist, idx = tree.query(fire_coords, k=1)

matched = fvc_df.iloc[idx.flatten()].reset_index(drop=True)
fire_df["FVC_VALUE"] = matched["FVC_VALUE"]
fire_df["FVC_DISTANCE_KM"] = dist.flatten() * 6371  # Convert from radians to km

# %%
fire_df.head(4)
# Out:
#                             incident_id incident_name  \
# 0  2ca11d45-8139-4c16-8af0-880d99b21e82   Bridge Fire
# 1  f904489b-0488-4764-9a98-bd3b818d1756      111 Fire
# 2  f9e85371-fc46-4f54-822c-7dcdaadde551      152 Fire
# 3  ca7da36b-1951-4d52-92b2-1a0b04aab586      241 Fire
#
#   incident_date_last_update incident_date_created  incident_acres_burned  \
# 0      2018-01-09T13:46:00Z  2017-10-31T11:22:00Z                   37.0
# 1      2022-05-01T22:29:02Z  2022-04-30T20:33:00Z                   15.0
# 2      2013-06-05T08:30:00Z  2013-06-04T15:42:00Z                  124.0
# 3      2015-07-15T18:45:00Z  2015-07-13T10:47:00Z                  214.0
#
#    incident_longitude  incident_latitude incident_dateonly_created  \
# 0         -122.309000          40.774000                2017-10-31
# 1         -115.916687          33.510716                2022-04-30
# 2         -121.006939          37.037760                2013-06-04
# 3         -117.727400          33.762600                2015-07-13
#
#    DayAirTmpAvg01  DayPrecip01  ...  CBD_DISTANCE_KM  EVC_VALUE  \
# 0             9.6          0.0  ...      1216.028099        251
# 1            22.3          0.0  ...       548.933201        125
# 2            20.2          0.0  ...       788.094762         31
# 3            27.4          0.0  ...       470.160274        166
#
#            EVC_LABEL  EVC_DISTANCE_KM  FBFM_VALUE  FBFM_DISTANCE_KM  \
# 0  Shrub Cover = 51%      1216.028099       -9999       1216.028099
# 1   Tree Cover = 25%       548.933201       -9999        548.933201
# 2             Barren       788.094762       -9999        788.094762
# 3   Tree Cover = 66%       470.160274       -9999        470.160274
#
#    FDIST_VALUE  FDIST_DISTANCE_KM  FVC_VALUE  FVC_DISTANCE_KM
# 0          112        1216.028099        125      1216.028099
# 1          112         548.933201        106       548.933201
# 2          113         788.094762        111       788.094762
# 3          112         470.160274        106       470.160274
#
# [4 rows x 90 columns]

# %%
fire_df.to_csv(os.path.join(project_path, "data/landfire_data/finalized/calfire_landfire_cimis_merged.csv"))
